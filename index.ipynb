# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
df = pd.read_csv("A202001.csv.gz",sep=";",nrows=10000)
df.head()
# Out:
#    FLX_ANN_MOI  ORG_CLE_REG  AGE_BEN_SNDS  BEN_RES_REG  BEN_CMU_TOP  \
# 0       202001           53            70           53            0
# 1       202001           32            70           32            0
# 2       202001           28            80           28            0
# 3       202001           32            80           32            0
# 4       202001           53            60           53            0
#
#    BEN_QLT_COD  BEN_SEX_COD  DDP_SPE_COD  ETE_CAT_SNDS  ETE_REG_COD  ...  \
# 0            1            1          121          9999           99  ...
# 1            1            1          121          9999           99  ...
# 2            1            1          121          9999           99  ...
# 3            2            2          121          9999           99  ...
# 4            1            2          121          9999           99  ...
#
#    PSE_ACT_CAT  PSE_SPE_SNDS  PSE_STJ_SNDS  PRE_INS_REG  PSP_ACT_SNDS  \
# ...

# %%
#1. Montant de dépenses totales par nature de préstation  (bar)
sns.barplot(x="PSE_SPE_SNDS",y="PRS_PAI_MNT",data=df)
# Out:
# <AxesSubplot:xlabel='PSE_SPE_SNDS', ylabel='PRS_PAI_MNT'>

# %%
df.BEN_SEX_COD.where(df["PSE_SPE_SNDS"]==0).value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df.BEN_SEX_COD.where(df["PSE_SPE_SNDS"]==15).value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df.BEN_SEX_COD.where(df["PSE_SPE_SNDS"]==3).value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df.BEN_SEX_COD.where(df["PSE_SPE_SNDS"]==6).value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df.BEN_SEX_COD.where(df["PSE_SPE_SNDS"]==36).value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df.BEN_SEX_COD.where(df["PSE_SPE_SNDS"]==35).value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df = df.
